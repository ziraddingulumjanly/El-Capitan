# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ```{image} images/copy.png
# :alt: K-Fold Cross Validation Diagram
# :width: 50%
# :align: center
# ```

# %% [markdown]
# ```{note}
# Here is a note!
# ```

# %% [markdown]
# ```{admonition} Here's your admonition
# Here's the admonition content
# ```

# %%
from sklearn import show_versions
show_versions()
# Out:
# System:
#     python: 3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]
# executable: c:\Users\zirad\AppData\Local\Programs\Python\Python312\python.exe
#    machine: Windows-11-10.0.26200-SP0
#
# Python dependencies:
#       sklearn: 1.7.1
#           pip: 26.0.1
#    setuptools: 75.6.0
#         numpy: 2.0.2
#         scipy: 1.16.1
#        Cython: None
#        pandas: 2.3.1
#    matplotlib: 3.10.3
#        joblib: 1.5.1
# threadpoolctl: 3.6.0
#
# Built with OpenMP: True
#
# threadpoolctl info:
#        user_api: openmp
#    internal_api: openmp
#     num_threads: 12
#          prefix: vcomp
#        filepath: C:\Users\zirad\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\.libs\vcomp140.dll
#         version: None
#
#        user_api: blas
#    internal_api: openblas
#     num_threads: 12
#          prefix: libscipy_openblas
#        filepath: C:\Users\zirad\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy.libs\libscipy_openblas64_-caad452230ae4ddb57899b8b3a33c55c.dll
#         version: 0.3.27
# threading_layer: pthreads
#    architecture: Zen
#
#        user_api: blas
#    internal_api: openblas
#     num_threads: 12
#          prefix: libscipy_openblas
#        filepath: C:\Users\zirad\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy.libs\libscipy_openblas-6b2103f2ae4d8547998b5d188e9801fb.dll
#         version: 0.3.28
# threading_layer: pthreads
#    architecture: Haswell
