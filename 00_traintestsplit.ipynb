# %%
df =
X = df.drop(columns=[], axis=1)
y = df[""]

from sklearn.model_selecttion import train_test_split
# train_test_split(X,y,train_size = 0.9,random_state=1)
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    train_size = 0.9,
    random_state=1
    )

```{Note}
Note: from sklearn model_selection those things can be added: 
Random and Grid Search, train test split and Cross Validation such as StratifiedKFold
from sklearn.model_selection import (
    train_test_split,
    StratifiedKFold,
    cross_validate,
    GridSearchCV
)
```

# %%
````{admonition} Mathematical Background
:class: note

The following concepts from `sklearn.model_selection` are not required to understand the core workflow, but they are commonly used in real-world machine learning projects:

- `train_test_split`
- `StratifiedKFold`
- `cross_validate`
- `GridSearchCV`
- Random Search

Example imports:

```python
from sklearn.model_selection import (
    train_test_split,
    StratifiedKFold,
    cross_validate,
    GridSearchCV
)
```
